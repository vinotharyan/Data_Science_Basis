# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv('C:\\Users\\admin\\Downloads\\cars1.csv')
cars2 = pd.read_csv('C:\\Users\\admin\\Downloads\\cars2.csv')

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.drop(cars1.columns[cars1.columns.str.contains('unnamed',case = False)],axis = 1,inplace=True)

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print( 'the number of observations of cars1 dataset is {}'.format(len(cars1)))
print( 'the number of observations of cars2 dataset is {}'.format(len(cars2)))
# Out:
# the number of observations of cars1 dataset is 198
# the number of observations of cars2 dataset is 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.merge(cars1, cars2, how = 'outer', on = None, left_on = None, left_index = False, sort = False, 
                suffixes = ('_x', '_y'), copy = True, indicator = False, validate = None)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners = [i for i in np.random.randint(15000, 73000, (len(cars)-1))]
owners
# Out:
# [37540,
#  64902,
#  50737,
#  21269,
#  34806,
#  45781,
#  31454,
#  62126,
#  27691,
#  41154,
#  17128,
#  48904,
#  62381,
#  66748,
#  17478,
#  25874,
#  43204,
#  16011,
#  38345,
#  24902,
#  35004,
#  23368,
#  22146,
#  29489,
#  34571,
#  59510,
#  62410,
#  66384,
#  24854,
#  45446,
#  25374,
#  42070,
#  48563,
#  51057,
#  41731,
#  55680,
#  31315,
#  34402,
#  58098,
#  24077,
#  69281,
#  59516,
#  62808,
#  35272,
#  15443,
#  61707,
#  43842,
#  42459,
#  31795,
#  22445,
#  43614,
#  31373,
#  71149,
#  35532,
#  45481,
#  61671,
#  38241,
#  71865,
#  22930,
#  34215,
#  70416,
#  38089,
#  26684,
#  43248,
#  69790,
#  59947,
#  24999,
#  18918,
#  48358,
#  66703,
#  51882,
#  51590,
#  15690,
#  56949,
#  66422,
#  18062,
#  16513,
#  30615,
#  15477,
#  48864,
#  67902,
#  50183,
#  22412,
#  32451,
#  28013,
#  37685,
#  17406,
#  63425,
#  49271,
#  45679,
#  54709,
#  63515,
#  59345,
#  39806,
#  51047,
#  35720,
#  65912,
#  67763,
#  46935,
#  19601,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars=pd.concat([cars, pd.DataFrame({'owners': owners})], axis = 1, join = 'outer')
cars.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
# 5  15.0          8           429        198    4341          10.0     70
# 6  14.0          8           454        220    4354           9.0     70
# 7  14.0          8           440        215    4312           8.5     70
# 8  14.0          8           455        225    4425          10.0     70
# 9  15.0          8           390        190    3850           8.5     70
#
#    origin                        car   owners
# 0       1  chevrolet chevelle malibu  37540.0
# 1       1          buick skylark 320  64902.0
# ...
