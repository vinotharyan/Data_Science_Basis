# %%
sc

# %%
spar_rea=sc.textFile("/FileStore/tables/spark_info.txt")

# %%
spar_rea.collect()

# %%
spp=spar_rea.filter(lambda line : 'Apache' in line)

# %%
type(spp)

# %%
spp.collect()

# %%
spps=spar_rea.filter(lambda line:'Spark' in line)

# %%
spps.collect()

# %%
spp_s=spar_rea.filter(lambda line: 'Data' in line)

# %%
spp_s.collect()

# %%
ma=spar_rea.map(lambda line:line.split(" "))

# %%
ma.collect()

# %%
ss=spar_rea.flatMap(lambda line:line.split(" "))

# %%
ss.collect()

# %%
wod=ss.map(lambda word: (word,1))

# %%
wod.collect()

# %%
word_count=wod.reduceByKey(lambda x,y:x+y)

# %%
word_count.collect()

# %%
word_count.take(10)

# %%
word_count.first()

# %%
sc

# %%
iris=sc.textFile("/FileStore/tables/iris.txt")

# %%
iris.collect()

# %%
iris.count()

# %%
setosa=iris.filter(lambda line:'Iris-setosa' in line)

# %%
setosa.collect()

# %%
setosa.count()

# %%
seto=setosa.flatMap(lambda line:line.split(","))

# %%
seto.collect()

# %%
seto_c=seto.map(lambda word:(word,1))

# %%
seto_c.collect()

# %%
count_words=seto_c.reduceByKey(lambda a,b:a+b)

# %%
count_words.collect()

# %%
count_words.first()

# %%
count_words.take(46)

# %%
text_file = sc.textFile("/FileStore/tables/iris.txt")
versicolor=iris.filter(lambda line:'Iris-versicolor' in line)
counts = versicolor.flatMap(lambda line: line.split(","))

# %%
counts.collect()

# %%
versicolor_c=counts.map(lambda word:(word,1))

versicolor_c.collect()

# %%
counts=versicolor_c.reduceByKey(lambda a,b:a+b)

# %%
counts.collect()

# %%
text_file = sc.textFile("/FileStore/tables/iris.txt")
virginica=iris.filter(lambda line:'Iris-virginica' in line)
couts = virginica.flatMap(lambda line: line.split(","))
vig_c=couts.map(lambda word:(word,1))
co=vig_c.reduceByKey(lambda a,b:a+b)
#co.collect()
co.saveAsTextFile("/FileStore/tables/output.txt")

# %%
couts.collect()
co=couts.reduceByKey(lambda a,b:a+b)

# %%
# see the result
out=sc.textFile("/FileStore/tables/output.txt/part-00001")
out.collect()
