# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('C:\\Users\\admin\\Downloads\\student-mat.csv')
df.head(6)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1   at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1   at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2    health  services ...
# 4     GP   F   16       U     GT3       T     3     3     other     other ...
# 5     GP   M   16       U     LE3       T     4     3  services     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
# 5      5        4      2     1     2      5       10  15  15  15
#
# [6 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.iloc[:,0:12].head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
df['Mjob']=map(lambda x: x.capitalize(), df['Mjob'])
df['Mjob'].head(5)
# Out:
# 0    At_home
# 1    At_home
# 2    At_home
# 3     Health
# 4      Other
# Name: Mjob, dtype: object

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Fjob'].str.upper().head(10)
# Out:
# 0     TEACHER
# 1       OTHER
# 2       OTHER
# 3    SERVICES
# 4       OTHER
# 5       OTHER
# 6       OTHER
# 7     TEACHER
# 8       OTHER
# 9       OTHER
# Name: Fjob, dtype: object

# %%
df['Mjob'] = map(lambda x: x.upper(), df['Mjob'])
df['Mjob'].head()
# Out:
# 0    AT_HOME
# 1    AT_HOME
# 2    AT_HOME
# 3     HEALTH
# 4      OTHER
# Name: Mjob, dtype: object

# %%
df['Fjob'] = map(lambda x: x.upper(), df['Fjob'])
df['Fjob'].head()
# Out:
# 0     TEACHER
# 1       OTHER
# 2       OTHER
# 3    SERVICES
# 4       OTHER
# Name: Fjob, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.drop(['lower','upper'] ,axis=1, inplace=True)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#      ...     freetime goout  Dalc  Walc  health absences  G1  G2  G3  \
# 0    ...            3     4     1     1       3        6   5   6   6
# 1    ...            3     3     1     1       3        4   5   5   6
# 2    ...            3     2     2     3       3       10   7   8  10
# 3    ...            2     2     1     1       5        2  15  14  15
# 4    ...            3     2     1     2       5        4   6  10  10
#
#   upper_desc
# 0         gp
# 1         gp
# 2         gp
# 3         gp
# 4         gp
#
# [5 rows x 34 columns]

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  \
# 394     MS   M   19       U     LE3       T     1     1  other  at_home
#
#       ...   Dalc Walc  health  absences  G1 G2 G3 upper_desc lower   upper
# 394   ...      3    3       5         5   8  9  9         ms    ms  COURSE
#
# [1 rows x 36 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob'] = map(lambda x: x.upper(), df['Mjob'])
df['Mjob'].head()
# Out:
# 0    AT_HOME
# 1    AT_HOME
# 2    AT_HOME
# 3     HEALTH
# 4      OTHER
# Name: Mjob, dtype: object

# %%
df['Mjob'] = map(lambda x: x.upper(), df['Mjob'])
df['Mjob'].head()
# Out:
# 0    AT_HOME
# 1    AT_HOME
# 2    AT_HOME
# 3     HEALTH
# 4      OTHER
# Name: Mjob, dtype: object

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
df['legal_drink'] = df['age'] >17

# %%
df['legal_drink'].head(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: legal_drink, dtype: bool

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
df.select_dtypes(exclude=['object']) * 10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# 5    160    40    30          10         20         0      50        40
# 6    160    20    20          10         20         0      40        40
# 7    170    40    40          20         20         0      40        10
# 8    150    30    20          10         20         0      40        20
# 9    150    30    40          10         20         0      50        50
# 10   150    40    40          10         20         0      30        30
# 11   150    20    10          30         30         0      50        20
# 12   150    40    40          10         10         0      40        30
# 13   150    40    30          20         20         0      50        40
# 14   150    20    20          10         30         0      40        50
# 15   160    40    40          10         10         0      40        40
# 16   160    40    40          10         30         0      30        20
# 17   160    30    30          30         20         0      50        30
# 18   170    30    20          10         10        30      50        50
# 19   160    40    30          10         10         0      30        10
# 20   150    40    30          10         20         0      40        40
# 21   150    40    40          10         10         0      50        40
# 22   160    40    20          10         20         0      40        50
# 23   160    20    20          20         20         0      50        40
# 24   150    20    40          10         30         0      40        30
# 25   160    20    20          10         10        20      10        20
# 26   150    20    20          10         10         0      40        20
# 27   150    40    20          10         10         0      20        20
# 28   160    30    40          10         20         0      50        30
# 29   160    40    40          10         20         0      40        40
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 365  180    10    30          20         20         0      30        30
# 366  180    40    40          20         30         0      40        20
# 367  170    10    10          30         10        10      50        20
# 368  180    20    30          20         10         0      50        20
# 369  180    40    40          30         20         0      30        20
# 370  190    30    20          20         20        20      30        20
# 371  180    10    20          30         10         0      40        30
# 372  170    20    20          10         30         0      30        40
# 373  170    10    20          10         10         0      30        50
# 374  180    40    40          20         30         0      50        40
# 375  180    10    10          40         30         0      40        30
# 376  200    40    20          20         30        20      50        40
# 377  180    40    40          10         20         0      50        40
# 378  180    30    30          10         20         0      40        10
# 379  170    30    10          10         20         0      40        50
# 380  180    40    40          10         20         0      30        20
# 381  180    20    10          20         10         0      40        40
# 382  170    20    30          20         20         0      40        40
# 383  190    10    10          20         10        10      40        30
# 384  180    40    20          20         10        10      50        40
# 385  180    20    20          20         30         0      50        30
# 386  180    40    40          30         10         0      40        40
# 387  190    20    30          10         30        10      50        40
# 388  180    30    10          10         20         0      40        30
# 389  180    10    10          20         20        10      10        10
# 390  200    20    20          10         20        20      50        50
# 391  170    30    10          20         10         0      20        40
# 392  210    10    10          10         10        30      50        50
# 393  180    30    20          30         10         0      40        40
# 394  190    10    10          10         10         0      30        20
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3 legal_drink
# 0       40    10    10      30        60   50   60   60          10
# 1       30    10    10      30        40   50   50   60           0
# 2       20    20    30      30       100   70   80  100           0
# 3       20    10    10      50        20  150  140  150           0
# 4       20    10    20      50        40   60  100  100           0
# 5       20    10    20      50       100  150  150  150           0
# 6       40    10    10      30         0  120  120  110           0
# 7       40    10    10      10        60   60   50   60           0
# 8       20    10    10      10         0  160  180  190           0
# 9       10    10    10      50         0  140  150  150           0
# 10      30    10    20      20         0  100   80   90           0
# 11      20    10    10      40        40  100  120  120           0
# 12      30    10    30      50        20  140  140  140           0
# 13      30    10    20      30        20  100  100  110           0
# 14      20    10    10      30         0  140  160  160           0
# 15      40    10    20      20        40  140  140  140           0
# 16      30    10    20      20        60  130  140  140           0
# 17      20    10    10      40        40   80  100  100           0
# 18      50    20    40      50       160   60   50   50           0
# 19      30    10    30      50        40   80  100  100           0
# 20      10    10    10      10         0  130  140  150           0
# 21      20    10    10      50         0  120  150  150           0
# 22      10    10    30      50        20  150  150  160           0
# 23      40    20    40      50         0  130  130  120           0
# 24      20    10    10      50        20  100   90   80           0
# 25      20    10    30      50       140   60   90   80           0
# 26      20    10    20      50        20  120  120  110           0
# 27      40    20    40      10        40  150  160  150           0
# 28      30    10    10      50        40  110  110  110           0
# 29      50    50    50      50       160  100  120  110           0
# ..     ...   ...   ...     ...       ...  ...  ...  ...         ...
# 365     40    20    40      30        40  100  100  100          10
# 366     20    20    20      50         0  130  130  130          10
# 367     10    10    20      10         0   70   60    0           0
# 368     30    10    20      40         0  110  100  100          10
# 369     20    40    20      50       100  140  120  110          10
# 370     20    10    10      30        40   70   70   90          10
# 371     30    20    30      30        30  140  120  120          10
# 372     30    10    10      30        80  130  110  110           0
# 373     50    10    30      10       140   60   50   50           0
# 374     40    10    10      10         0  190  180  190          10
# 375     20    10    20      40        20   80   80  100          10
# 376     30    10    10      30        40  150  140  150          10
# 377     30    30    40      20        40   80   90  100          10
# 378     30    10    20      10         0  150  150  150          10
# 379     40    20    30      10       170  100  100  100           0
# 380     40    10    40      20        40  150  140  140          10
# 381     30    10    30      50        50   70   60   70          10
# 382     30    10    10      30        20  110  110  100           0
# 383     20    10    30      50         0   60   50    0          10
# 384     30    40    30      30       140   60   50   50          10
# 385     30    10    30      40        20  100   90  100          10
# 386     30    20    20      50        70   60   50   60          10
# 387     20    10    20      50         0   70   50    0          10
# 388     40    10    10      10         0   70   90   80          10
# 389     10    10    10      50         0   60   50    0          10
# 390     40    40    50      40       110   90   90   90          10
# 391     50    30    40      20        30  140  160  160           0
# 392     30    30    30      30        30  100   80   70          10
# 393     10    30    40      50         0  110  120  100          10
# 394     30    30    30      50        50   80   90   90          10
#
# [395 rows x 17 columns]
